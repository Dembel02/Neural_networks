# %% [markdown]
# # Распознавание изображений из набора данных Cifar10

# %% [markdown]
# **Импорт библиотек для работы всего ноутбука**

# %%
from tensorflow.keras.datasets import cifar10
from keras.utils import get_file

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, Adadelta
from tensorflow.keras import utils
from tensorflow.keras.preprocessing import image

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import random
import math
import zipfile
import os

# %%
# Загружаем cifar 10
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Загружаем cifar 10
# ----> 2 (x_train, y_train), (x_test, y_test) = cifar10.load_data()
#
# File c:\Python312\Lib\site-packages\keras\src\datasets\cifar10.py:65, in load_data()
#      63 dirname = "cifar-10-batches-py-target"
#      64 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 65 path = get_file(
#      66     fname=dirname,
#      67     origin=origin,
#      68     extract=True,
#      69     file_hash=(  # noqa: E501
#      70         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      71     ),
#      72 )
#      74 num_train_samples = 50000
#      76 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# ...

# %%
from keras.datasets import cifar10
from keras.utils import get_file

(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[13], line 4
#       1 from keras.datasets import cifar10
#       2 from keras.utils import get_file
# ----> 4 (x_train, y_train), (x_test, y_test) = cifar10.load_data()
#
# File c:\Python312\Lib\site-packages\keras\src\datasets\cifar10.py:65, in load_data()
#      63 dirname = "cifar-10-batches-py-target"
#      64 origin = "https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz"
# ---> 65 path = get_file(
#      66     fname=dirname,
#      67     origin=origin,
#      68     extract=True,
#      69     file_hash=(  # noqa: E501
#      70         "6d958be074577803d12ecdefd02955f39262c83c16fe9348329d7fe0b5c001ce"
#      71     ),
#      72 )
#      74 num_train_samples = 50000
#      76 x_train = np.empty((num_train_samples, 3, 32, 32), dtype="uint8")
#
# ...

# %%
x_train.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 x_train.shape
#
# NameError: name 'x_train' is not defined

# %%
# Определяем названия классов по порядку
classes = ['самолет', 'автомобиль', 'птица', 'кот', 'олень', 'собака', 'лягушка', 'лошадь', 'корабль', 'грузовик']

# %%
# выводим для примера картинки по каждому классу

fig, axs = plt.subplots(1, 10, figsize=(25, 3)) # Создаем полотно из 10 графиков
for i in range(10): # проходим по классам от 0 до 9
    label_indexes = np.where(y_train==i)[0] # Получаем список из индексов положении класса i в y_train
    index = random.choice(label_indexes) # Случайным образом выбираем из списка индекс
    img = x_train[index] # Выбираем из x_train нужное изображение
    axs[i].imshow(Image.fromarray(img)) # Отображаем i-ым графиком

plt.show() # Показываем изображения
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       3 fig, axs = plt.subplots(1, 10, figsize=(25, 3)) # Создаем полотно из 10 графиков
#       4 for i in range(10): # проходим по классам от 0 до 9
# ----> 5     label_indexes = np.where(y_train==i)[0] # Получаем список из индексов положении класса i в y_train
#       6     index = random.choice(label_indexes) # Случайным образом выбираем из списка индекс
#       7     img = x_train[index] # Выбираем из x_train нужное изображение
#
# NameError: name 'y_train' is not defined
